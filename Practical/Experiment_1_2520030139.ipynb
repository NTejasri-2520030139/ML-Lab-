# %%
import pandas as pd
# File name
CSV_PATH = "placement_predict_50k.csv"
# Read CSV file
df = pd.read_csv(CSV_PATH)
# 1. Display first 5 rows
print("FIRST 5 ROWS")
print(df.head())
# 2. Display dataset shape
print("\nDATASET SHAPE")
print(df.shape)
# 3. Display column names
print("\nCOLUMN NAMES")
print(df.columns)
# 4. Display data types
print("\nDATA TYPES")
print(df.dtypes)
# 5. Display basic information
print("\nDATASET INFORMATION")
df.info()
# 6. Display statistical summary
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# 7. Check missing values
print("\nMISSING VALUES")
print(df.isnull().sum())
# 8. Check duplicate rows
print("\nDUPLICATE ROWS")
print(df.duplicated().sum())
# 9. Placement status distribution
print("\nPLACEMENT STATUS DISTRIBUTION")
print(df["PlacementStatus"].value_counts())
# 10. Placement status percentage
print("\nPLACEMENT STATUS PERCENTAGE")
print(df["PlacementStatus"].value_counts(normalize=True) * 100)
# Out:
# FIRST 5 ROWS
#    StudentID  Gender       City CollegeTier      Stream Specialisation Hostel  \
# 0          1  Female      Delhi       Tier3          IT    DataScience    Yes
# 1          2    Male    Chennai       Tier2         ECE             AI    Yes
# 2          3  Female  Hyderabad       Tier3         ECE     Networking     No
# 3          4  Female     Jaipur       Tier3         ECE       Embedded     No
# 4          5    Male  Ahmedabad       Tier3  Mechanical    DataScience     No
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  Publications  \
# 0               Yes       6.39       6.84  ...               1             0
# 1                No       5.95       6.74  ...               2             0
# 2                No       7.13       8.11  ...               2             1
# 3                No       9.37       9.97  ...               6             2
# 4                No       8.25       8.99  ...               4             2
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# 0               62.3              6.57             40.6                65.7
# 1               44.0              5.86             40.3                51.8
# 2               73.8              7.50             73.6                67.9
# 3              100.0              9.41             98.7                 NaN
# 4               90.8              9.24             83.1               100.0
#
#    ExtraCurricular  CGPA_Tier  PlacementStatus  IsAnomaly
# 0               No     Medium              0.0        0.0
# 1               No     Medium              0.0        0.0
# 2               No       High              1.0        0.0
# 3               No  Excellent              1.0        0.0
# 4               No  Excellent              1.0        0.0
#
# [5 rows x 31 columns]
#
# DATASET SHAPE
# (45303, 31)
#
# COLUMN NAMES
# Index(['StudentID', 'Gender', 'City', 'CollegeTier', 'Stream',
#        'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'SGPA_Sem1',
#        'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6',
#        'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships',
#        'Projects', 'Workshops', 'Certifications', 'Publications',
#        'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore',
#        'MockInterviewScore', 'ExtraCurricular', 'CGPA_Tier', 'PlacementStatus',
#        'IsAnomaly'],
#       dtype='object')
#
# DATA TYPES
# StudentID               int64
# Gender                 object
# City                   object
# CollegeTier            object
# Stream                 object
# Specialisation         object
# Hostel                 object
# HistoryOfBacklogs      object
# SGPA_Sem1             float64
# SGPA_Sem2             float64
# SGPA_Sem3             float64
# SGPA_Sem4             float64
# SGPA_Sem5             float64
# SGPA_Sem6             float64
# SGPA_Sem7             float64
# SGPA_Sem8             float64
# CGPA                  float64
# AttendancePercent     float64
# Internships             int64
# Projects                int64
# Workshops             float64
# Certifications          int64
# Publications            int64
# AptitudeTestScore     float64
# SoftSkillsRating      float64
# CodingTestScore       float64
# MockInterviewScore    float64
# ExtraCurricular        object
# CGPA_Tier              object
# PlacementStatus       float64
# IsAnomaly             float64
# dtype: object
#
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45303 entries, 0 to 45302
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StudentID           45303 non-null  int64
#  1   Gender              45303 non-null  object
#  2   City                45303 non-null  object
#  3   CollegeTier         45303 non-null  object
#  4   Stream              45303 non-null  object
#  5   Specialisation      45303 non-null  object
#  6   Hostel              45303 non-null  object
#  7   HistoryOfBacklogs   45303 non-null  object
#  8   SGPA_Sem1           45303 non-null  float64
#  9   SGPA_Sem2           45303 non-null  float64
#  10  SGPA_Sem3           45303 non-null  float64
#  11  SGPA_Sem4           45303 non-null  float64
#  12  SGPA_Sem5           45303 non-null  float64
#  13  SGPA_Sem6           45303 non-null  float64
#  14  SGPA_Sem7           45303 non-null  float64
#  15  SGPA_Sem8           45303 non-null  float64
#  16  CGPA                45303 non-null  float64
#  17  AttendancePercent   45303 non-null  float64
#  18  Internships         45303 non-null  int64
#  19  Projects            45303 non-null  int64
#  20  Workshops           41270 non-null  float64
#  21  Certifications      45303 non-null  int64
#  22  Publications        45303 non-null  int64
#  23  AptitudeTestScore   41643 non-null  float64
#  24  SoftSkillsRating    42110 non-null  float64
#  25  CodingTestScore     42613 non-null  float64
#  26  MockInterviewScore  40789 non-null  float64
#  27  ExtraCurricular     45303 non-null  object
#  28  CGPA_Tier           45302 non-null  object
#  29  PlacementStatus     45302 non-null  float64
#  30  IsAnomaly           45302 non-null  float64
# dtypes: float64(17), int64(5), object(9)
# memory usage: 10.7+ MB
#
# STATISTICAL SUMMARY
#           StudentID     SGPA_Sem1     SGPA_Sem2     SGPA_Sem3     SGPA_Sem4  \
# count  45303.000000  45303.000000  45303.000000  45303.000000  45303.000000
# mean   22652.000000      7.190190      7.224724      7.253727      7.280266
# std    13077.993959      1.056831      1.054788      1.055607      1.053307
# min        1.000000      4.000000      4.000000      4.000000      4.000000
# 25%    11326.500000      6.480000      6.520000      6.550000      6.570000
# 50%    22652.000000      7.200000      7.230000      7.260000      7.280000
# 75%    33977.500000      7.910000      7.940000      7.970000      8.000000
# max    45303.000000     10.000000     10.000000     10.000000     10.000000
#
#           SGPA_Sem5     SGPA_Sem6     SGPA_Sem7     SGPA_Sem8          CGPA  \
# count  45303.000000  45303.000000  45303.000000  45303.000000  45303.000000
# mean       7.311162      7.343224      7.373668      7.403264      7.297519
# std        1.055771      1.053210      1.054485      1.055738      1.003471
# min        4.000000      4.000000      4.000000      4.000000      4.000000
# 25%        6.600000      6.630000      6.660000      6.690000      6.620000
# 50%        7.320000      7.350000      7.380000      7.400000      7.300000
# 75%        8.030000      8.060000      8.100000      8.130000      7.980000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...      Projects     Workshops  Certifications  Publications  \
# count  ...  45303.000000  41270.000000    45303.000000  45303.000000
# mean   ...      2.531422      2.051030        2.253272      0.508178
# std    ...      1.493818      1.371968        1.521076      0.619370
# min    ...      0.000000      0.000000        0.000000      0.000000
# 25%    ...      1.000000      1.000000        1.000000      0.000000
# 50%    ...      3.000000      2.000000        2.000000      0.000000
# 75%    ...      4.000000      3.000000        3.000000      1.000000
# max    ...      8.000000      6.000000        8.000000      3.000000
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# count       41643.000000      42110.000000     42613.000000
# mean           64.836762          6.485160        59.833257
# std            15.936273          1.597057        18.989362
# min             2.300000          0.080000         0.000000
# 25%            54.200000          5.410000        47.000000
# 50%            64.900000          6.490000        60.000000
# 75%            75.800000          7.590000        72.900000
# max           100.000000         10.000000       100.000000
#
#        MockInterviewScore  PlacementStatus     IsAnomaly
# count        40789.000000     45302.000000  45302.000000
# mean            64.857616         0.474703      0.024348
# std             15.987015         0.499365      0.154128
# min              0.000000         0.000000      0.000000
# 25%             54.000000         0.000000      0.000000
# 50%             64.900000         0.000000      0.000000
# 75%             75.800000         1.000000      0.000000
# max            100.000000         1.000000      1.000000
#
# [8 rows x 22 columns]
#
# MISSING VALUES
# StudentID                0
# Gender                   0
# City                     0
# CollegeTier              0
# Stream                   0
# Specialisation           0
# Hostel                   0
# HistoryOfBacklogs        0
# SGPA_Sem1                0
# SGPA_Sem2                0
# SGPA_Sem3                0
# SGPA_Sem4                0
# SGPA_Sem5                0
# SGPA_Sem6                0
# SGPA_Sem7                0
# SGPA_Sem8                0
# CGPA                     0
# AttendancePercent        0
# Internships              0
# Projects                 0
# Workshops             4033
# Certifications           0
# Publications             0
# AptitudeTestScore     3660
# SoftSkillsRating      3193
# CodingTestScore       2690
# MockInterviewScore    4514
# ExtraCurricular          0
# CGPA_Tier                1
# PlacementStatus          1
# IsAnomaly                1
# dtype: int64
#
# DUPLICATE ROWS
# 0
#
# PLACEMENT STATUS DISTRIBUTION
# PlacementStatus
# 0.0    23797
# 1.0    21505
# Name: count, dtype: int64
#
# PLACEMENT STATUS PERCENTAGE
# PlacementStatus
# 0.0    52.52969
# 1.0    47.47031
# Name: proportion, dtype: float64
